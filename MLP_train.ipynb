# %%
import numpy as np
import pandas as pd
from pandas import read_csv
import torch
import torch.nn as nn
from torch.utils.data import DataLoader,TensorDataset
import torch.optim as optim
from models import MLP
import matplotlib.pyplot as plt

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# ## Data Preprocessing

# %%
df_train = pd.read_csv('intern_homework_train_dataset.csv')
df_test = pd.read_csv('intern_homework_public_test_dataset.csv')

has_update = df_train['title'].str.contains('#更新|\(更新\)|\(更\)|#更|2更|更2|更\)|\(更').astype(int)
df_train['update'] = has_update

has_update = df_test['title'].str.contains('#更新|\(更新\)|\(更\)|#更|2更|更2|更\)|\(更').astype(int)
df_test['update'] = has_update

df_train['created_at'] = pd.to_datetime(df_train['created_at'], format='%Y-%m-%d %H:%M:%S %Z')
df_train['hour'] = df_train['created_at'].apply(lambda x: x.hour)
df_train['weekday'] = df_train['created_at'].apply(lambda x: x.weekday)

df_test['created_at'] = pd.to_datetime(df_test['created_at'], format='%Y-%m-%d %H:%M:%S %Z')
df_test['hour'] = df_test['created_at'].apply(lambda x: x.hour)
df_test['weekday'] = df_test['created_at'].apply(lambda x: x.weekday)

df_train_label = df_train["like_count_24h"]
df_train_input = df_train.drop(['author_id', 'like_count_24h', 'forum_id', 'created_at', 'title'], axis=1)

df_test_label = df_test["like_count_24h"]
df_test_input = df_test.drop(['author_id', 'like_count_24h', 'forum_id', 'created_at', 'title'], axis=1)

train_input = df_train_input.values
train_label = df_train_label.values
test_input = df_test_input.values
test_label = df_test_label.values

# %% [markdown]
# ## DataLoader

# %%
TrainBatchSize = 5000
TestBatchSize = 2000

train_input = torch.Tensor(train_input)
train_label = torch.Tensor(train_label)

test_input = torch.Tensor(test_input)
test_label = torch.Tensor(test_label)

train = TensorDataset(train_input, train_label)
train_dataload = DataLoader(train, batch_size=TrainBatchSize, shuffle=True)

test = TensorDataset(test_input, test_label)
test_dataload = DataLoader(test, batch_size=TestBatchSize, shuffle=False)

# %% [markdown]
# ## MLP Training

# %%
MLP_model = MLP()
MLP_model.to(device)
optimizer = optim.Adam(MLP_model.parameters(), lr=0.01, weight_decay=0.001)
min_loss=100.0
train_plot = []
test_plot = []

for epoch in range(1000):
   
    MLP_model.train()
    train_loss = 0.0
    correct = 0
    
    for i, (data, label) in enumerate(train_dataload):
        
        data = data.to(device)
        label = label.to(device)
        
        # clear gradient
        optimizer.zero_grad()

        # Forward propagation
        output = MLP_model(data)
    
        label = torch.reshape(label, (TrainBatchSize, 1))
        
        # Calculate MAPE
        loss = torch.mean(torch.abs((label - output) / label) * 100)/(50000/TrainBatchSize)
        
        # Calculate gradients
        loss.backward()

        # Update parameters
        optimizer.step()
        
        train_loss += loss.item()
    
    train_plot.append(train_loss)
    if((epoch+1)%10==0):
        print("---------------------------------------")
        print("{}th epoch training Loss: ".format(epoch+1))
        print(train_loss)
    
    MLP_model.eval()
    with torch.no_grad():
    
        test_loss = 0.0
        correct = 0
        
        for i, (data, label) in enumerate(test_dataload):
            
            data = data.to(device)
            label = label.to(device)
            
            output = MLP_model(data)
            output[output < 5] = 5
            label = torch.reshape(label, (TestBatchSize, 1))
            
            loss = torch.mean(torch.abs((label - output) / label) * 100)/(10000/TestBatchSize)
        
            test_loss += loss.item()
    
    test_plot.append(test_loss)
    if((epoch+1)%10==0):
        print("{}th epoch testing Loss: ".format(epoch+1))
        print(test_loss)
    
    if(test_loss<min_loss):
        min_loss=test_loss
    
    if(test_loss<=30.1):
        torch.save(MLP_model, 'best_model.pt')

print("Minimum Loss: ")
print(min_loss)
# Out:
# ---------------------------------------
# 10th epoch training Loss:
# 31.59526252746582
# 10th epoch testing Loss:
# 32.68810701370239
# ---------------------------------------
# 20th epoch training Loss:
# 30.7864990234375
# 20th epoch testing Loss:
# 31.777812957763672
# ---------------------------------------
# 30th epoch training Loss:
# 30.34091877937317
# 30th epoch testing Loss:
# 31.90329122543335
# ---------------------------------------
# 40th epoch training Loss:
# 30.16845464706421
# 40th epoch testing Loss:
# 31.63116979598999
# ---------------------------------------
# 50th epoch training Loss:
# 29.4933660030365
# 50th epoch testing Loss:
# 31.435558795928955
# ---------------------------------------
# 60th epoch training Loss:
# 29.39879584312439
# 60th epoch testing Loss:
# 30.97070550918579
# ---------------------------------------
# 70th epoch training Loss:
# 29.3064227104187
# 70th epoch testing Loss:
# 31.089273929595947
# ---------------------------------------
# 80th epoch training Loss:
# 29.17149543762207
# 80th epoch testing Loss:
# 31.061745643615723
# ---------------------------------------
# 90th epoch training Loss:
# 29.043205499649048
# 90th epoch testing Loss:
# 31.225608825683594
# ---------------------------------------
# 100th epoch training Loss:
# 29.116241693496704
# 100th epoch testing Loss:
# 30.816935539245605
# ---------------------------------------
# 110th epoch training Loss:
# 28.961095333099365
# 110th epoch testing Loss:
# 31.021507263183594
# ---------------------------------------
# 120th epoch training Loss:
# 29.0146427154541
# 120th epoch testing Loss:
# 31.234277725219727
# ---------------------------------------
# 130th epoch training Loss:
# 28.914369583129883
# 130th epoch testing Loss:
# 30.823930740356445
# ---------------------------------------
# 140th epoch training Loss:
# 29.072051763534546
# 140th epoch testing Loss:
# 30.843114852905273
# ---------------------------------------
# 150th epoch training Loss:
# 28.80095076560974
# 150th epoch testing Loss:
# 30.784242630004883
# ---------------------------------------
# 160th epoch training Loss:
# 28.73012685775757
# 160th epoch testing Loss:
# 30.7899432182312
# ---------------------------------------
# 170th epoch training Loss:
# 28.970481157302856
# 170th epoch testing Loss:
# 30.789610385894775
# ---------------------------------------
# 180th epoch training Loss:
# 29.873833656311035
# 180th epoch testing Loss:
# 31.561091423034668
# ---------------------------------------
# 190th epoch training Loss:
# 28.753008604049683
# 190th epoch testing Loss:
# 30.821510314941406
# ---------------------------------------
# 200th epoch training Loss:
# 28.612043857574463
# 200th epoch testing Loss:
# 30.694743633270264
# ---------------------------------------
# 210th epoch training Loss:
# 28.579688549041748
# 210th epoch testing Loss:
# 30.69965124130249
# ---------------------------------------
# 220th epoch training Loss:
# 28.754095315933228
# 220th epoch testing Loss:
# 30.74846363067627
# ---------------------------------------
# 230th epoch training Loss:
# 28.595393180847168
# 230th epoch testing Loss:
# 30.717655181884766
# ---------------------------------------
# 240th epoch training Loss:
# 28.581880569458008
# 240th epoch testing Loss:
# 30.69456672668457
# ---------------------------------------
# 250th epoch training Loss:
# 28.593231201171875
# 250th epoch testing Loss:
# 30.963160037994385
# ---------------------------------------
# 260th epoch training Loss:
# 29.2833092212677
# 260th epoch testing Loss:
# 30.875464916229248
# ---------------------------------------
# 270th epoch training Loss:
# 28.756378412246704
# 270th epoch testing Loss:
# 30.91285753250122
# ---------------------------------------
# 280th epoch training Loss:
# 28.76160740852356
# 280th epoch testing Loss:
# 31.188590049743652
# ---------------------------------------
# 290th epoch training Loss:
# 28.47516942024231
# 290th epoch testing Loss:
# 30.657307624816895
# ---------------------------------------
# 300th epoch training Loss:
# 28.714372634887695
# 300th epoch testing Loss:
# 30.665059566497803
# ---------------------------------------
# 310th epoch training Loss:
# 28.511729955673218
# 310th epoch testing Loss:
# 30.643430709838867
# ---------------------------------------
# 320th epoch training Loss:
# 28.652771949768066
# 320th epoch testing Loss:
# 30.736653804779053
# ---------------------------------------
# 330th epoch training Loss:
# 28.80266785621643
# 330th epoch testing Loss:
# 30.991682529449463
# ---------------------------------------
# 340th epoch training Loss:
# 28.792170763015747
# 340th epoch testing Loss:
# 30.92926836013794
# ---------------------------------------
# 350th epoch training Loss:
# 29.899556398391724
# 350th epoch testing Loss:
# 31.7302885055542
# ---------------------------------------
# 360th epoch training Loss:
# 28.952110052108765
# 360th epoch testing Loss:
# 30.664838314056396
# ---------------------------------------
# 370th epoch training Loss:
# 28.586414575576782
# 370th epoch testing Loss:
# 30.73208999633789
# ---------------------------------------
# 380th epoch training Loss:
# 28.759105443954468
# 380th epoch testing Loss:
# 30.60940170288086
# ---------------------------------------
# 390th epoch training Loss:
# 28.436091899871826
# 390th epoch testing Loss:
# 30.62857675552368
# ---------------------------------------
# 400th epoch training Loss:
# 29.215444564819336
# 400th epoch testing Loss:
# 31.18461322784424
# ---------------------------------------
# 410th epoch training Loss:
# 28.716400384902954
# 410th epoch testing Loss:
# 30.800775051116943
# ---------------------------------------
# 420th epoch training Loss:
# 29.136940479278564
# 420th epoch testing Loss:
# 31.054287910461426
# ---------------------------------------
# 430th epoch training Loss:
# 29.483426809310913
# 430th epoch testing Loss:
# 31.191418170928955
# ---------------------------------------
# 440th epoch training Loss:
# 28.56292176246643
# 440th epoch testing Loss:
# 30.848111152648926
# ---------------------------------------
# 450th epoch training Loss:
# 28.546387434005737
# 450th epoch testing Loss:
# 30.493349075317383
# ---------------------------------------
# 460th epoch training Loss:
# 28.506287574768066
# 460th epoch testing Loss:
# 30.709518909454346
# ---------------------------------------
# 470th epoch training Loss:
# 28.607407808303833
# 470th epoch testing Loss:
# 30.82602882385254
# ---------------------------------------
# 480th epoch training Loss:
# 28.625132083892822
# 480th epoch testing Loss:
# 30.524827003479004
# ---------------------------------------
# 490th epoch training Loss:
# 28.9008047580719
# 490th epoch testing Loss:
# 30.727388858795166
# ---------------------------------------
# 500th epoch training Loss:
# 29.13596200942993
# 500th epoch testing Loss:
# 31.446303367614746
# ---------------------------------------
# 510th epoch training Loss:
# 28.471312522888184
# 510th epoch testing Loss:
# 30.552013397216797
# ---------------------------------------
# 520th epoch training Loss:
# 28.459296941757202
# 520th epoch testing Loss:
# 30.563151359558105
# ---------------------------------------
# 530th epoch training Loss:
# 28.432730197906494
# 530th epoch testing Loss:
# 30.546081066131592
# ---------------------------------------
# 540th epoch training Loss:
# 28.500636339187622
# 540th epoch testing Loss:
# 30.729886054992676
# ---------------------------------------
# 550th epoch training Loss:
# 28.355825662612915
# 550th epoch testing Loss:
# 30.61971092224121
# ---------------------------------------
# 560th epoch training Loss:
# 28.41357111930847
# 560th epoch testing Loss:
# 30.56233024597168
# ---------------------------------------
# 570th epoch training Loss:
# 28.43522572517395
# 570th epoch testing Loss:
# 30.549827098846436
# ---------------------------------------
# 580th epoch training Loss:
# 29.0229275226593
# 580th epoch testing Loss:
# 31.106574535369873
# ---------------------------------------
# 590th epoch training Loss:
# 28.314737558364868
# 590th epoch testing Loss:
# 30.678588390350342
# ---------------------------------------
# 600th epoch training Loss:
# 28.2648503780365
# 600th epoch testing Loss:
# 30.70258331298828
# ---------------------------------------
# 610th epoch training Loss:
# 28.337380170822144
# 610th epoch testing Loss:
# 30.783299446105957
# ---------------------------------------
# 620th epoch training Loss:
# 28.395576000213623
# 620th epoch testing Loss:
# 30.522526741027832
# ---------------------------------------
# 630th epoch training Loss:
# 28.214970588684082
# 630th epoch testing Loss:
# 30.441108226776123
# ---------------------------------------
# 640th epoch training Loss:
# 28.319666147232056
# 640th epoch testing Loss:
# 30.591102123260498
# ---------------------------------------
# 650th epoch training Loss:
# 28.37724280357361
# 650th epoch testing Loss:
# 30.527660369873047
# ---------------------------------------
# 660th epoch training Loss:
# 28.225197792053223
# 660th epoch testing Loss:
# 30.73973512649536
# ---------------------------------------
# 670th epoch training Loss:
# 28.237800121307373
# 670th epoch testing Loss:
# 30.553298950195312
# ---------------------------------------
# 680th epoch training Loss:
# 28.411972999572754
# 680th epoch testing Loss:
# 30.56394863128662
# ---------------------------------------
# 690th epoch training Loss:
# 28.23308038711548
# 690th epoch testing Loss:
# 30.485039710998535
# ---------------------------------------
# 700th epoch training Loss:
# 28.376028299331665
# 700th epoch testing Loss:
# 30.38963794708252
# ---------------------------------------
# 710th epoch training Loss:
# 28.472601175308228
# 710th epoch testing Loss:
# 30.643115997314453
# ---------------------------------------
# 720th epoch training Loss:
# 28.398565769195557
# 720th epoch testing Loss:
# 30.56549310684204
# ---------------------------------------
# 730th epoch training Loss:
# 28.2283136844635
# 730th epoch testing Loss:
# 30.367857933044434
# ---------------------------------------
# 740th epoch training Loss:
# 28.309019088745117
# 740th epoch testing Loss:
# 30.56735897064209
# ---------------------------------------
# 750th epoch training Loss:
# 28.264084339141846
# 750th epoch testing Loss:
# 30.57858896255493
# ---------------------------------------
# 760th epoch training Loss:
# 28.339221715927124
# 760th epoch testing Loss:
# 30.596730709075928
# ---------------------------------------
# 770th epoch training Loss:
# 28.48593258857727
# 770th epoch testing Loss:
# 31.003187656402588
# ---------------------------------------
# 780th epoch training Loss:
# 28.327226877212524
# 780th epoch testing Loss:
# 30.441818714141846
# ---------------------------------------
# 790th epoch training Loss:
# 28.41863775253296
# 790th epoch testing Loss:
# 30.39417552947998
# ---------------------------------------
# 800th epoch training Loss:
# 28.22101664543152
# 800th epoch testing Loss:
# 30.49409818649292
# ---------------------------------------
# 810th epoch training Loss:
# 28.237128496170044
# 810th epoch testing Loss:
# 30.4047589302063
# ---------------------------------------
# 820th epoch training Loss:
# 28.28949475288391
# 820th epoch testing Loss:
# 30.46153497695923
# ---------------------------------------
# 830th epoch training Loss:
# 29.259876489639282
# 830th epoch testing Loss:
# 30.962509632110596
# ---------------------------------------
# 840th epoch training Loss:
# 28.510443925857544
# 840th epoch testing Loss:
# 30.700019359588623
# ---------------------------------------
# 850th epoch training Loss:
# 28.295477390289307
# 850th epoch testing Loss:
# 30.72842836380005
# ---------------------------------------
# 860th epoch training Loss:
# 28.330090045928955
# 860th epoch testing Loss:
# 30.306527614593506
# ---------------------------------------
# 870th epoch training Loss:
# 28.24204993247986
# 870th epoch testing Loss:
# 30.57628345489502
# ---------------------------------------
# 880th epoch training Loss:
# 28.41474676132202
# 880th epoch testing Loss:
# 30.75547981262207
# ---------------------------------------
# 890th epoch training Loss:
# 28.148058652877808
# 890th epoch testing Loss:
# 30.43797779083252
# ---------------------------------------
# 900th epoch training Loss:
# 28.213197946548462
# 900th epoch testing Loss:
# 30.554725170135498
# ---------------------------------------
# 910th epoch training Loss:
# 28.38988947868347
# 910th epoch testing Loss:
# 30.93981409072876
# ---------------------------------------
# 920th epoch training Loss:
# 28.230369567871094
# 920th epoch testing Loss:
# 30.46005630493164
# ---------------------------------------
# 930th epoch training Loss:
# 28.429887294769287
# 930th epoch testing Loss:
# 30.43761682510376
# ---------------------------------------
# 940th epoch training Loss:
# 28.252422094345093
# 940th epoch testing Loss:
# 30.499171257019043
# ---------------------------------------
# 950th epoch training Loss:
# 28.23106098175049
# 950th epoch testing Loss:
# 30.567938327789307
# ---------------------------------------
# 960th epoch training Loss:
# 28.43560266494751
# 960th epoch testing Loss:
# 30.871752738952637
# ---------------------------------------
# 970th epoch training Loss:
# 28.146491289138794
# 970th epoch testing Loss:
# 30.440465927124023
# ---------------------------------------
# 980th epoch training Loss:
# 28.111572980880737
# 980th epoch testing Loss:
# 30.668986320495605
# ---------------------------------------
# 990th epoch training Loss:
# 28.21514868736267
# 990th epoch testing Loss:
# 30.51145601272583
# ---------------------------------------
# 1000th epoch training Loss:
# 28.52459168434143
# 1000th epoch testing Loss:
# 30.541441917419434
# Minimum Loss:
# 30.240095138549805

# %% [markdown]
# ## Plotting

# %%
x = np.arange(1000)
plt.plot(x, train_plot, label='Training loss')
plt.plot(x, test_plot, label='Validation loss')

plt.xlabel('Epoch')
plt.ylabel('MAPE(%)')
plt.title('MLP Learning curve')
plt.legend()

plt.show()
